# %%
# import bibliotek
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


#zaczytanie pliku dat
df = pd.read_csv('cross-section.dat', sep = ',')
df
# Out:
#       nodenumber      x-coordinate      y-coordinate      z-coordinate  \
# 0              1         -0.043888          0.701550         -0.043888
# 1              2         -0.043881          0.705494         -0.043881
# 2              3         -0.042891          0.705494         -0.042891
# 3              4         -0.042899          0.701550         -0.042899
# 4              5         -0.042881          0.709919         -0.042881
# ...          ...               ...               ...               ...
# 6687        6688         -0.009854          0.172145         -0.009854
# 6688        6689          0.000000          0.158750          0.000000
# 6689        6690         -0.009979          0.158217         -0.009979
# 6690        6691          0.000000          0.145000          0.000000
# 6691        6692         -0.010105          0.144290         -0.010105
#
#             co_ppm_dry        no_ppm_dry            o2_dry           co2_dry  \
# ...

# %%
for row in df:
    data['o2_dry_limited'] =
    
cols = ['b']
df[cols] = df[df[cols] > 0][cols]
df.dropna()
# Out:
#   File "<ipython-input-16-0267eb95b69f>", line 2
#     if
#       ^
# SyntaxError: invalid syntax
